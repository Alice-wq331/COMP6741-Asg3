# %%
import random
nb_dic={}
parameter=[]
with open('Pace2024-Testsets/medium_test_set/instances/1.gr', 'r') as file:
    i=0
    for line in file:
        x=line.strip().split()
        if i==0:
            parameter.append(int(x[2]))
            parameter.append(int(x[3]))
            parameter.append(int(x[4]))
        else:
            a=int(x[0])
            b=int(x[1])
            if b not in nb_dic.keys():
                nb_dic[b]=[a]
            else:
                nb_dic[b].append(a)
        i+=1
n=parameter[0];n0=parameter[1];m=parameter[2]
bls=[i for i in range(n+1,n+n0+1)]
random.seed(0)
def split_sort(b):
    if len(b)==0:
        return []
    elif len(b)==1:
        return b
    n=len(b)
    idx=random.randint(0,n-1)
    pivot_u=b[idx]
    lls=[]
    rls=[]
    if  pivot_u not in nb_dic.keys():
            for i in range(n):
                if i==idx:
                    continue
                lls.append(b[i])
            return (split_sort(lls)+[pivot_u])
    nb_u=nb_dic[pivot_u]
    for i in range(n):
        if i==idx:
            continue
        v=b[i]
        if v not in nb_dic.keys():
                lls.append(v)
                continue
        nb_v=nb_dic[v]
        c_uv=0
        cross_nbs=0
        for a in range(len(nb_u)):
            cur_line=nb_u[a]
            c_uv+=cross_nbs
            while cross_nbs!=len(nb_v):
                if nb_v[cross_nbs]<cur_line:
                    cross_nbs+=1
                    c_uv+=1
                else:
                    break          
        c_vu=0
        cross_nbs=0
        for a in range(len(nb_v)):
            cur_line=nb_v[a]
            c_vu+=cross_nbs
            while cross_nbs!=len(nb_u):
                if nb_u[cross_nbs]<cur_line:
                    cross_nbs+=1
                    c_vu+=1
                else:
                    break
        if c_vu<c_uv:
            lls.append(v)
        else:
            rls.append(v)
    return (split_sort(lls)+[pivot_u]+split_sort(rls))
orderedls=split_sort(bls)       
with open('Pace2024-Testsets/medium_test_set/test_solutions/1.sol', 'w') as file:
    for item in orderedls:
        file.write(f"{item}\n")
# Out:
# /tmp/ipykernel_951/2469283396.py:22: DeprecationWarning: Seeding based on hashing is deprecated
# since Python 3.9 and will be removed in a subsequent version. The only
# supported seed types are: None, int, float, str, bytes, and bytearray.
#   random.seed(Integer(0))

# %%
#For medium size sets
import random
def create_sol(filepath,outputpath):
    nb_dic={}
    parameter=[]
    with open(filepath, 'r') as file:
        i=0
        for line in file:
            x=line.strip().split()
            if i==0:
                parameter.append(int(x[2]))
                parameter.append(int(x[3]))
                parameter.append(int(x[4]))
            else:
                a=int(x[0])
                b=int(x[1])
                if b not in nb_dic.keys():
                    nb_dic[b]=[a]
                else:
                    nb_dic[b].append(a)
            i+=1
    n=parameter[0];n0=parameter[1];m=parameter[2]
    bls=[i for i in range(n+1,n+n0+1)]
    random.seed(0)
    def split_sort(b):
        if len(b)==0:
            return []
        elif len(b)==1:
            return b
        n=len(b)
        idx=random.randint(0,n-1)
        pivot_u=b[idx]
        lls=[]
        rls=[]
        if  pivot_u not in nb_dic.keys():
            for i in range(n):
                if i==idx:
                    continue
                lls.append(b[i])
            return (split_sort(lls)+[pivot_u])
        nb_u=nb_dic[pivot_u]
        for i in range(n):
            if i==idx:
                continue
            v=b[i]
            if v not in nb_dic.keys():
                lls.append(v)
                continue
            nb_v=nb_dic[v]
            c_uv=0
            cross_nbs=0
            for a in range(len(nb_u)):
                cur_line=nb_u[a]
                c_uv+=cross_nbs
                while cross_nbs!=len(nb_v):
                    if nb_v[cross_nbs]<cur_line:
                        cross_nbs+=1
                        c_uv+=1
                    else:
                        break          
            c_vu=0
            cross_nbs=0
            for a in range(len(nb_v)):
                cur_line=nb_v[a]
                c_vu+=cross_nbs
                while cross_nbs!=len(nb_u):
                    if nb_u[cross_nbs]<cur_line:
                        cross_nbs+=1
                        c_vu+=1
                    else:
                        break
            if c_vu<c_uv:
                lls.append(v)
            else:
                rls.append(v)
        return (split_sort(lls)+[pivot_u]+split_sort(rls))
    orderedls=split_sort(bls)       
    with open(outputpath, 'w') as file:
        for item in orderedls:
            file.write(f"{item}\n")
for j in range(1,61):
    filepath='Pace2024-Testsets/medium_test_set/instances/'+str(j)+'.gr'
    outputpath='Pace2024-Testsets/medium_test_set/test_solutions/'+str(j)+'.sol'
    create_sol(filepath,outputpath)
# Out:
# /tmp/ipykernel_951/3200751239.py:24: DeprecationWarning: Seeding based on hashing is deprecated
# since Python 3.9 and will be removed in a subsequent version. The only
# supported seed types are: None, int, float, str, bytes, and bytearray.
#   random.seed(Integer(0))

# %%
#for tiny sets
import os
directory_path = 'Pace2024-Testsets/tiny_test_set/instances/'

# List all files in the directory
file_list = os.listdir(directory_path)

# Print the list of filenames
for filename in file_list:
    filepath='Pace2024-Testsets/tiny_test_set/instances/'+filename
    outputpath='Pace2024-Testsets/tiny_test_set/test_solutions/'+filename[:-3]+'.sol'
    create_sol(filepath,outputpath)
# Out:
# /tmp/ipykernel_951/3200751239.py:24: DeprecationWarning: Seeding based on hashing is deprecated
# since Python 3.9 and will be removed in a subsequent version. The only
# supported seed types are: None, int, float, str, bytes, and bytearray.
#   random.seed(Integer(0))
